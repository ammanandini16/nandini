# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib as mat
from tabulate import tabulate
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Placement_Data_Full_Class.csv')
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # Level 0

# %% [markdown]
# # INFORMATION OF DATA

# %%
data.info
# Out:
# <bound method DataFrame.info of      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # FINDING NULL VALUE

# %%
data.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# # SEPRATING THE NUMERICAL AND CATERGORICAL DATA

# %%
data_num_obj=data.select_dtypes(exclude='object')#numerical
data_num_obj
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0        1  67.00  91.00     58.00     55.0  58.80  270000.0
# 1        2  79.33  78.33     77.48     86.5  66.28  200000.0
# 2        3  65.00  68.00     64.00     75.0  57.80  250000.0
# 3        4  56.00  52.00     52.00     66.0  59.43       NaN
# 4        5  85.80  73.60     73.30     96.8  55.50  425000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 210    211  80.60  82.00     77.60     91.0  74.49  400000.0
# 211    212  58.00  60.00     72.00     74.0  53.62  275000.0
# 212    213  67.00  67.00     73.00     59.0  69.72  295000.0
# 213    214  74.00  66.00     58.00     70.0  60.23  204000.0
# 214    215  62.00  58.00     53.00     89.0  60.22       NaN
#
# [215 rows x 7 columns]

# %%
# THERE ARE 7 COLUMNS IN THE NUMERICAL DATA

# %%
data_cat_obj=df.select_dtypes(include='object')#catergorical
data_cat_obj
# Out:
#     gender    ssc_b    hsc_b     hsc_s   degree_t workex specialisation  \
# 0        M   Others   Others  Commerce   Sci&Tech     No         Mkt&HR
# 1        M  Central   Others   Science   Sci&Tech    Yes        Mkt&Fin
# 2        M  Central  Central      Arts  Comm&Mgmt     No        Mkt&Fin
# 4        M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# 7        M  Central  Central   Science   Sci&Tech    Yes        Mkt&Fin
# ..     ...      ...      ...       ...        ...    ...            ...
# 209      M  Central  Central  Commerce  Comm&Mgmt     No        Mkt&Fin
# 210      M   Others   Others  Commerce  Comm&Mgmt     No        Mkt&Fin
# 211      M   Others   Others   Science   Sci&Tech     No        Mkt&Fin
# 212      M   Others   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin
# 213      F   Others   Others  Commerce  Comm&Mgmt     No         Mkt&HR
#
#      status
# 0    Placed
# 1    Placed
# 2    Placed
# 4    Placed
# 7    Placed
# ..      ...
# ...

# %%
# THERE ARE 8 COLUMNS IN THE CATERGORICAL DATA

# %% [markdown]
# # FILTERING PLACED AND NOT PLACED STUDENT

# %% [markdown]
# # PLACED STUDENT

# %%
dfplaced=data[(data.status=='Placed')]
dfplaced
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %% [markdown]
# # NOT PLACED

# %%
dfnot_placed=data[(data.status=='Not Placed')]
dfnot_placed
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %% [markdown]
# # LEVEL 1 - UNIVARIATE ANALYSIS

# %% [markdown]
#  # To check how many students are placed and not placed

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
sb.countplot(x='status',data=data)
plt.subplot(122)

per=data['status'].value_counts()
l=data['status'].unique()
plt.pie(per,labels=l,autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1fb2758ceb0>,
# ...
#  [Text(-0.6136307402963239, 0.9129388339661019, 'Placed'),
#   Text(0.6136306548208184, -0.9129388914183544, 'Not Placed')],
#  [Text(-0.33470767652526756, 0.4979666367087828, '68.84%'),
#   Text(0.3347076299022645, -0.49796666804637507, '31.16%')])

# %%
#placed student are high candidate than non placed

# %% [markdown]
# # To check which degree student are placed more

# %%
sb.countplot(x='degree_t',data=data)
# Out:
# <Axes: xlabel='degree_t', ylabel='count'>

# %%
#students are mostly placed are from commerence & mangement degree

# %% [markdown]
# # To check which stream student in the higher secondary are placed

# %%
sb.countplot(x='hsc_s',data=data)
# Out:
# <Axes: xlabel='hsc_s', ylabel='count'>

# %%
# from the analysis commerce student are more placed than science and arts

# %% [markdown]
# # To check which specialisation student are placed more

# %%
sb.countplot(x='specialisation',data=data)
# Out:
# <Axes: xlabel='specialisation', ylabel='count'>

# %%
#marketing & finance are more placed than marketing & HR

# %% [markdown]
# # LEVEL  2 - BIVARIATE ANALYSIS

# %% [markdown]
# # To check out which gender students are placed more

# %%
sb.countplot(x=data["status"],hue=data["gender"])
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
#male candidate placed more than female

# %% [markdown]
# # To check out which specialisation student are placed more

# %%
sb.countplot(x=data["specialisation"],hue=data["status"])
# Out:
# <Axes: xlabel='specialisation', ylabel='count'>

# %%
#marketing&finance student are placed more than MK&HR

# %% [markdown]
# # To checkout which degree % student are placed high

# %%
sb.histplot(x=df["degree_p"],hue=dfplaced["status"])
# Out:
# <Axes: xlabel='degree_p', ylabel='Count'>

# %%
#from the above histogram 63% to 64% secured percentage in degree student has got mostly placed

# %% [markdown]
# # To checkout in which hsc_p the salary is high

# %%
sb.lineplot(x=data["hsc_p"],y=data["salary"])
# Out:
# <Axes: xlabel='hsc_p', ylabel='salary'>

# %%
#the student secured btw 60 to 70% in there higher secondary are placed with high salary

# %% [markdown]
# # To checkout in which ssc_p the salary is high

# %%
sb.lineplot(x=data["ssc_p"],y=data["salary"])
# Out:
# <Axes: xlabel='ssc_p', ylabel='salary'>

# %%
##the student secured btw 60 to 63% in there senior secondary are placed with high salary

# %% [markdown]
# # LEVEL 3- MULTIVARITANT ANAYLSIS

# %% [markdown]
# # CORRELATION TABLE

# %%
corr_matrix=data.corr()
plt.figure(figsize=(12,8))
sb.heatmap(corr_matrix ,annot=True)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\amman\AppData\Local\Temp\ipykernel_13044\656261826.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix=data.corr()

# %%
#degree_p is strongly postively related to ssc_p
#hsc_p is postively related ssc_p
#salary is strongly negative degree_P
#ssc_p is negatively related to salary

# %% [markdown]
# # PAIR PLOT 1

# %%
sb.pairplot(data,hue='status',vars=['salary','hsc_p','ssc_p'],kind='reg',diag_kind='kde')

# %%
#from pair plot high salary are mostly for placed student
#the student with  high % in hsc_p is placed more
#the student with  high % in ssc_p is placed more

# %% [markdown]
# # PAIR PLOT 2

# %%
sb.pairplot(data,hue='status',vars=['salary','degree_p','mba_p'],kind='reg',diag_kind='kde')

# %%
#from pair plot high salary are mostly for placed student
#the student with  high % in degree_p is placed more
#the student with  high % in mba_p is placed more

# %% [markdown]
# # CONCULSION
# male students are placed more the female
# marketing&finance student are placed more than MK&HR
# students are mostly placed are from commerence & mangement degree
# the student secured btw 60 to 63% in there senior secondary are placed with high salary
# from the analysis commerce student are more placed than science and arts
